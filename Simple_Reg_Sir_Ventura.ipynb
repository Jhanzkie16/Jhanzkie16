# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Jhanzkie16/BSIS_Jann2/refs/heads/main/Salary_Data1.csv')

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df_clean = df.dropna(subset=['Years of Experience', 'Salary'])

# Redefine X and y with the cleaned data
X_clean = df_clean[['Years of Experience']]
y_clean = df_clean['Salary']

# Now fit the model with cleaned data
simple_model = LinearRegression()
simple_model.fit(X_clean, y_clean)
# Out:
# LinearRegression()

# %%
# Impute missing values in X_simple using the mean strategy (or other strategies)
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X_simple)

# Now, make predictions with the imputed data
y_pred = simple_model.predict(X_imputed)

print(y_pred)
# Out:
# [ 93517.11681432  79423.58012626 163984.80025459 ...  86470.34847029
#  156938.03191056  65330.04343821]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(f"Intercept: {simple_model.intercept_}, Coefficient: {simple_model.coef_[0]}")
# Out:
# Intercept: 58283.27509417885, Coefficient: 7046.7683440275105

# %%
plt.scatter(X_simple, y, color='red')
plt.plot(X_simple, y_pred, color='blue')
plt.title("Simple Linear Regression (Salary, Years of Experience)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
print(y_pred.max())
# Out:
# 297873.3987911142

# %%
print(y_pred.min())
# Out:
# 58283.27509417885
